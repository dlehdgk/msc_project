# %%
from functions import *
import matplotlib.pyplot as plt
import scipy.optimize as op
from scipy.integrate import odeint

# %%
#%% fitting to obtain numerical solution for recomb rate
#initial guess
a_guess = np.array([2e-13, 0.8])
#initialise values for recomb coefficient
z = np.linspace(700, 1700, 2000)
a_data = a_ex(z)

fit_a, cov_a = op.curve_fit(exp_fit, z, a_data, a_guess)

# %%
#alpha ex fit check

plt.plot(z, exp_fit(z, fit_a[0], fit_a[1]), label='fit')
plt.plot(z, a_data, label='$\\alpha_{\mathrm{ex}}$')
plt.legend()
plt.grid()
plt.show()

# %%
# C check
def C(z,X):
    C1 = 1+Lambda*K(z)*(1-X)*ng(z)*eta
    C2 = 1+Lambda*K(z)*(1-X)*ng(z)*eta*(Lambda+b_over_a(z)*exp_fit(z, fit_a[0], fit_a[1]))
    return C1/C2
print(C(1000,0))
# Out:
# 0.011223955781160299

# %%
#contour map of C x = redshift y = ionisation fraction
x = np.linspace(600, 1200, 1000)
y = np.linspace(0, 1, 1000)
xx,yy = np.meshgrid(x,y)
cc = C(xx,yy)

# %%
plt.contourf(xx, yy, cc, 50, cmap='RdGy')
plt.xlabel('redshift')
plt.ylabel('ionisation fraction')
plt.grid()
plt.colorbar()
plt.savefig('Images/C map.png', dpi=300)
plt.show()

# %%
#checking photon density and hubble param
Hu = Hubble(x)
n_g = ng(x)

# %%
plt.plot(x, Hu)
plt.ylabel('Hubble parameter [s^-1]')
plt.grid()
plt.show()

# %%
plt.plot(x, n_g)
plt.ylabel('photon number density [cm^-3]')
plt.grid()
plt.show()

# %%
#rate of recomb v rate of photoionisation
def rate_a(z, X):
    return exp_fit(z, fit_a[0], fit_a[1])*X*X*eta*ng(z)
def rate_b(z, X):
    return b_over_a(z)*exp_fit(z, fit_a[0], fit_a[1])*np.exp(-ly/Temp(z))*(1-X)

# %%
xnew = np.linspace(800, 1400, 1000)
ynew = np.linspace(0, 1, 1000)
X,Y = np.meshgrid(xnew, ynew)
a = rate_a(X, Y)
b = rate_b(X, Y)

# %%
plt.contourf(X, Y, a, 50, cmap='jet')
plt.xlabel('redshift')
plt.ylabel('ionisation fraction')
plt.grid()
plt.colorbar()
plt.show()

# %%
plt.contourf(X, Y, b, 50, cmap='jet')
plt.xlabel('redshift')
plt.ylabel('ionisation fraction')
plt.grid()
plt.colorbar()
plt.show()

# %%
delta = a-b
plt.contourf(X, Y, delta, 50, cmap='jet')
plt.xlabel('redshift')
plt.ylabel('ionisation fraction')
plt.grid()
plt.colorbar()
plt.show()

# %%
plt.contourf(X, Y, a, cmap='Reds',alpha=0.5)
plt.contourf(X, Y, b, cmap='Blues',alpha=0.5)
cont = plt.contour(X,Y, delta, 8, colors='black')
plt.clabel(cont, inline=True, fontsize=8)
plt.xlabel('redshift')
plt.ylabel('ionisation fraction')
plt.savefig('Images/a-b.png', dpi=300)
plt.grid()

# %%
testz = 1000
testX = 5e-4

print(rate_a(testz, testX)-rate_b(testz, testX))
print(rate_a(testz,testX))
# Out:
# 2.2069854143591362e-17
# 3.6910940645910504e-17

# %%
#function for differential equation of X
def X_diff(z, X):
    prefactor = 1/((1+z)*Hubble(z))
    return prefactor*(rate_a(z, X))*C(z, X)

# %%
diff_a = X_diff(X, Y)

# %%
plt.contourf(X, Y, diff_a, 50, cmap='jet')
plt.xlabel('redshift')
plt.ylabel('ionisation fraction')
plt.grid()
plt.colorbar()
plt.show()

# %%
print(X_diff(800, 1))
# Out:
# 3.787178921606769

# %%
#numerical integration of dX/dz
t = np.linspace(1700.0, 800.0, 1000)
sol_X = odeint(X_diff, 1, t, tfirst=True)
X = sol_X[:,0]

# %%
print(X)
# Out:
# [1.         0.99654248 0.99508996 0.9939656  0.99301026 0.99216239
#  0.99139048 0.99067582 0.99000625 0.98937332 0.98877091 0.98819437
#  0.98764011 0.98710529 0.9865876  0.98608513 0.98559629 0.98511974
#  0.98465434 0.98419909 0.98375315 0.98331575 0.98288624 0.98246402
#  0.98204858 0.98163943 0.98123617 0.9808384  0.98044579 0.980058
#  0.97967476 0.9792958  0.97892088 0.97854976 0.97818225 0.97781814
#  0.97745727 0.97709946 0.97674455 0.97639241 0.9760429  0.97569589
#  0.97535125 0.97500889 0.97466868 0.97433053 0.97399434 0.97366003
#  0.9733275  0.97299669 0.9726675  0.97233987 0.97201373 0.97168901
#  0.97136565 0.97104359 0.97072277 0.97040314 0.97008463 0.96976721
#  0.96945082 0.96913541 0.96882094 0.96850737 0.96819466 0.96788276
#  0.96757163 0.96726125 0.96695157 0.96664255 0.96633417 0.96602639
#  0.96571918 0.96541252 0.96510636 0.96480068 0.96449546 0.96419066
#  0.96388626 0.96358224 0.96327857 0.96297523 0.96267219 0.96236942
#  0.96206692 0.96176465 0.96146259 0.96116073 0.96085904 0.96055751
#  0.96025611 0.95995483 0.95965365 0.95935254 0.9590515  0.9587505
#  0.95844953 0.95814857 0.95784761 0.95754663 0.95724561 0.95694454
#  0.9566434  0.95634218 0.95604087 0.95573944 0.9554379  0.95513621
#  0.95483437 0.95453237 0.95423019 0.95392783 0.95362525 0.95332247
#  0.95301945 0.95271619 0.95241269 0.95210891 0.95180486 0.95150053
#  0.95119589 0.95089095 0.95058568 0.95028008 0.94997414 0.94966784
#  0.94936118 0.94905414 0.94874672 0.9484389  0.94813068 0.94782204
#  0.94751297 0.94720347 0.94689352 0.94658311 0.94627224 0.94596089
#  0.94564906 0.94533674 0.94502391 0.94471057 0.9443967  0.94408231
#  0.94376737 0.94345188 0.94313583 0.94281922 0.94250203 0.94218425
#  0.94186588 0.94154691 0.94122732 0.94090712 0.94058628 0.9402648
#  0.93994268 0.93961991 0.93929647 0.93897236 0.93864756 0.93832208
#  0.93799591 0.93766902 0.93734142 0.9370131  0.93668405 0.93635426
#  0.93602372 0.93569243 0.93536037 0.93502755 0.93469394 0.93435954
#  0.93402435 0.93368835 0.93335154 0.93301391 0.93267545 0.93233615
#  0.93199601 0.93165502 0.93131316 0.93097044 0.93062683 0.93028234
#  0.92993696 0.92959068 0.92924349 0.92889537 0.92854634 0.92819637
#  0.92784545 0.92749359 0.92714077 0.92678698 0.92643222 0.92607647
#  0.92571974 0.925362   0.92500326 0.9246435  0.92428272 0.92392091
#  0.92355806 0.92319416 0.92282921 0.92246319 0.9220961  0.92172793
#  0.92135867 0.92098831 0.92061684 0.92024427 0.91987057 0.91949574
#  0.91911977 0.91874265 0.91836438 0.91798495 0.91760434 0.91722255
#  0.91683958 0.9164554  0.91607002 0.91568343 0.91529561 0.91490655
#  0.91451626 0.91412472 0.91373192 0.91333786 0.91294252 0.91254589
#  0.91214797 0.91174875 0.91134822 0.91094638 0.9105432  0.91013869
#  0.90973283 0.90932561 0.90891703 0.90850708 0.90809575 0.90768303
#  0.9072689  0.90685337 0.90643642 0.90601804 0.90559822 0.90517696
#  0.90475424 0.90433006 0.9039044  0.90347726 0.90304863 0.90261849
#  0.90218685 0.90175368 0.90131897 0.90088273 0.90044494 0.90000559
#  0.89956467 0.89912216 0.89867807 0.89823238 0.89778508 0.89733616
#  0.89688561 0.89643342 0.89597959 0.89552409 0.89506692 0.89460807
#  0.89414754 0.8936853  0.89322135 0.89275569 0.89228829 0.89181914
#  0.89134825 0.89087559 0.89040116 0.88992495 0.88944694 0.88896712
#  0.88848549 0.88800204 0.88751674 0.8870296  0.88654059 0.88604972
#  0.88555696 0.88506231 0.88456575 0.88406728 0.88356689 0.88306455
#  0.88256027 0.88205403 0.88154581 0.88103561 0.88052342 0.88000922
#  0.879493   0.87897475 0.87845446 0.87793211 0.8774077  0.87688122
#  0.87635264 0.87582197 0.87528917 0.87475426 0.87421721 0.873678
#  0.87313664 0.8725931  0.87204737 0.87149944 0.87094931 0.87039695
#  0.86984235 0.8692855  0.86872639 0.868165   0.86760133 0.86703536
#  0.86646707 0.86589646 0.8653235  0.86474819 0.86417052 0.86359047
#  0.86300803 0.86242317 0.8618359  0.8612462  0.86065405 0.86005944
#  0.85946236 0.85886279 0.85826072 0.85765614 0.85704902 0.85643937
#  0.85582715 0.85521237 0.854595   0.85397504 0.85335246 0.85272725
#  0.8520994  0.8514689  0.85083572 0.85019986 0.8495613  0.84892003
#  0.84827602 0.84762928 0.84697977 0.84632749 0.84567242 0.84501455
#  0.84435386 0.84369034 0.84302396 0.84235473 0.84168261 0.8410076
#  0.84032968 0.83964883 0.83896505 0.8382783  0.83758859 0.83689588
#  0.83620017 0.83550144 0.83479968 0.83409486 0.83338698 0.83267601
#  0.83196194 0.83124476 0.83052444 0.82980098 0.82907434 0.82834453
#  0.82761152 0.8268753  0.82613584 0.82539314 0.82464717 0.82389792
#  0.82314537 0.82238951 0.82163032 0.82086778 0.82010187 0.81933257
#  0.81855988 0.81778377 0.81700423 0.81622123 0.81543476 0.81464481
#  0.81385135 0.81305437 0.81225385 0.81144977 0.81064212 0.80983088
#  0.80901603 0.80819755 0.80737542 0.80654963 0.80572016 0.80488699
#  0.8040501  0.80320948 0.8023651  0.80151695 0.80066501 0.79980926
#  0.79894968 0.79808626 0.79721897 0.7963478  0.79547273 0.79459374
#  0.79371081 0.79282393 0.79193307 0.79103822 0.79013936 0.78923646
#  0.78832952 0.78741851 0.78650341 0.78558421 0.78466088 0.78373341
#  0.78280177 0.78186596 0.78092595 0.77998171 0.77903324 0.77808052
#  0.77712351 0.77616222 0.77519661 0.77422667 0.77325237 0.77227371
#  0.77129065 0.77030319 0.7693113  0.76831496 0.76731415 0.76630886
#  0.76529907 0.76428475 0.76326589 0.76224247 0.76121447 0.76018187
#  0.75914466 0.75810281 0.7570563  0.75600511 0.75494924 0.75388865
#  0.75282333 0.75175326 0.75067842 0.7495988  0.74851437 0.74742511
#  0.74633101 0.74523205 0.74412821 0.74301947 0.74190581 0.74078722
#  0.73966367 0.73853515 0.73740164 0.73626312 0.73511957 0.73397099
#  0.73281733 0.7316586  0.73049477 0.72932582 0.72815174 0.72697251
#  0.72578811 0.72459852 0.72340373 0.72220372 0.72099848 0.71978798
#  0.71857221 0.71735115 0.71612479 0.71489311 0.71365609 0.71241371
#  0.71116597 0.70991284 0.70865431 0.70739037 0.70612099 0.70484616
#  0.70356588 0.70228011 0.70098885 0.69969209 0.6983898  0.69708198
#  0.6957686  0.69444967 0.69312515 0.69179504 0.69045933 0.689118
#  0.68777104 0.68641843 0.68506017 0.68369624 0.68232662 0.68095132
#  0.67957031 0.67818358 0.67679113 0.67539293 0.67398899 0.67257929
#  0.67116382 0.66974257 0.66831553 0.66688269 0.66544404 0.66399958
#  0.6625493  0.66109318 0.65963122 0.65816341 0.65668975 0.65521022
#  0.65372482 0.65223355 0.65073641 0.64923337 0.64772444 0.64620962
#  0.6446889  0.64316227 0.64162973 0.64009128 0.63854691 0.63699663
#  0.63544043 0.63387831 0.63231026 0.63073629 0.6291564  0.62757059
#  0.62597885 0.62438119 0.6227776  0.6211681  0.61955268 0.61793135
#  0.61630411 0.61467095 0.6130319  0.61138695 0.6097361  0.60807936
#  0.60641675 0.60474826 0.6030739  0.60139369 0.59970762 0.59801571
#  0.59631797 0.59461441 0.59290504 0.59118986 0.5894689  0.58774216
#  0.58600966 0.5842714  0.58252741 0.5807777  0.57902228 0.57726118
#  0.5754944  0.57372196 0.57194389 0.5701602  0.56837091 0.56657604
#  0.5647756  0.56296964 0.56115815 0.55934117 0.55751872 0.55569083
#  0.55385751 0.5520188  0.55017472 0.5483253  0.54647056 0.54461053
#  0.54274525 0.54087474 0.53899903 0.53711816 0.53523216 0.53334105
#  0.53144488 0.52954367 0.52763747 0.52572631 0.52381022 0.52188924
#  0.51996342 0.51803279 0.51609739 0.51415726 0.51221244 0.51026298
#  0.50830892 0.5063503  0.50438717 0.50241957 0.50044756 0.49847117
#  0.49649045 0.49450546 0.49251624 0.49052285 0.48852534 0.48652375
#  0.48451815 0.48250859 0.48049512 0.47847779 0.47645667 0.47443181
#  0.47240326 0.4703711  0.46833537 0.46629614 0.46425348 0.46220743
#  0.46015808 0.45810547 0.45604968 0.45399078 0.45192882 0.44986388
#  0.44779602 0.44572531 0.44365183 0.44157564 0.43949682 0.43741543
#  0.43533156 0.43324526 0.43115663 0.42906574 0.42697265 0.42487745
#  0.42278022 0.42068103 0.41857996 0.4164771  0.41437252 0.41226631
#  0.41015854 0.40804931 0.40593869 0.40382677 0.40171363 0.39959937
#  0.39748405 0.39536778 0.39325065 0.39113272 0.38901411 0.38689489
#  0.38477516 0.38265501 0.38053453 0.37841381 0.37629294 0.37417201
#  0.37205113 0.36993037 0.36780985 0.36568964 0.36356985 0.36145058
#  0.35933191 0.35721395 0.3550968  0.35298054 0.35086528 0.34875112
#  0.34663815 0.34452647 0.34241619 0.34030739 0.33820019 0.33609468
#  0.33399096 0.33188913 0.3297893  0.32769155 0.325596   0.32350274
#  0.32141188 0.31932351 0.31723774 0.31515467 0.3130744  0.31099703
#  0.30892267 0.30685141 0.30478335 0.3027186  0.30065726 0.29859942
#  0.2965452  0.29449468 0.29244798 0.29040519 0.28836641 0.28633174
#  0.28430128 0.28227514 0.2802534  0.27823617 0.27622355 0.27421564
#  0.27221253 0.27021432 0.2682211  0.26623298 0.26425005 0.26227241
#  0.26030014 0.25833335 0.25637213 0.25441656 0.25246675 0.25052278
#  0.24858476 0.24665276 0.24472688 0.2428072  0.24089383 0.23898684
#  0.23708632 0.23519236 0.23330505 0.23142446 0.22955069 0.22768382
#  0.22582392 0.22397109 0.2221254  0.22028692 0.21845575 0.21663195
#  0.21481561 0.2130068  0.21120558 0.20941205 0.20762627 0.20584831
#  0.20407824 0.20231613 0.20056206 0.19881608 0.19707826 0.19534868
#  0.19362738 0.19191445 0.19020993 0.18851388 0.18682637 0.18514746
#  0.1834772  0.18181564 0.18016285 0.17851887 0.17688375 0.17525756
#  0.17364032 0.1720321  0.17043294 0.16884289 0.16726198 0.16569027
#  0.16412778 0.16257458 0.16103068 0.15949614 0.15797098 0.15645524
#  0.15494895 0.15345215 0.15196487 0.15048713 0.14901897 0.14756041
#  0.14611147 0.14467219 0.14324258 0.14182266 0.14041246 0.139012
#  0.13762128 0.13624033 0.13486916 0.13350779 0.13215622 0.13081447
#  0.12948255 0.12816046 0.12684822 0.12554582 0.12425327 0.12297058
#  0.12169774 0.12043476 0.11918163 0.11793836 0.11670494 0.11548136
#  0.11426762 0.11306371 0.11186963 0.11068536 0.10951089 0.10834621
#  0.10719132 0.10604618 0.10491079 0.10378514 0.1026692  0.10156295
#  0.10046638 0.09937947 0.09830218 0.09723451 0.09617642 0.09512788
#  0.09408889 0.09305939 0.09203938 0.09102881 0.09002766 0.0890359
#  0.08805349 0.08708041 0.08611661 0.08516207 0.08421674 0.08328059
#  0.08235358 0.08143568 0.08052685 0.07962704 0.07873621 0.07785433
#  0.07698135 0.07611723 0.07526193 0.07441539 0.07357758 0.07274844
#  0.07192794 0.07111603 0.07031265 0.06951777 0.06873132 0.06795327
#  0.06718356 0.06642214 0.06566896 0.06492396 0.06418711 0.06345834
#  0.06273759 0.06202483 0.06131999 0.06062302 0.05993386 0.05925246
#  0.05857877 0.05791273 0.05725428 0.05660336 0.05595992 0.05532391
#  0.05469526 0.05407392 0.05345983 0.05285293 0.05225316 0.05166047
#  0.0510748  0.05049608 0.04992427 0.04935929 0.0488011  0.04824963
#  0.04770482 0.04716661 0.04663495 0.04610978 0.04559103 0.04507864
#  0.04457256 0.04407273 0.04357909 0.04309158 0.04261014 0.0421347
#  0.04166522 0.04120162 0.04074386 0.04029188 0.0398456  0.03940498
#  0.03896996 0.03854048 0.03811648 0.03769789 0.03728468 0.03687677
#  0.03647411 0.03607663 0.0356843  0.03529704 0.0349148  0.03453753
#  0.03416516 0.03379765 0.03343494 0.03307697 0.03272368 0.03237503
#  0.03203095 0.0316914  0.03135632 0.03102566 0.03069935 0.03037736
#  0.03005963 0.0297461  0.02943673 0.02913146 0.02883024 0.02853303
#  0.02823976 0.0279504  0.02766489 0.02738318 0.02710523 0.02683098
#  0.02656039 0.02629341 0.02602999 0.0257701  0.02551367 0.02526066
#  0.02501104 0.02476475 0.02452175 0.024282   0.02404544 0.02381205
#  0.02358177 0.02335457 0.0231304  0.02290922 0.02269099 0.02247566
#  0.02226321 0.02205358 0.02184674 0.02164265]

# %%
trunc = np.linspace(800, 1200, 100)
review_fit = rev_ex(trunc)
plt.plot(trunc, review_fit, label='$\propto z^{12.75}$')
plt.plot(t, X, label='excited X')
plt.plot(t, saha(t), label='saha')
plt.grid()
plt.legend()
plt.show()
